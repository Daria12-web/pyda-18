# %%
# Задание 1. Напишите функцию, которая возвращает название валюты (поле ‘Name’) с максимальным значением курса с помощью сервиса https://www.cbr-xml-daily.ru/daily_json.js

# %%
import requests

class Rate:
    def __init__(self, format_='value'):
        self.format = format_
    
    def exchange_rates(self):
        
        r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return r.json()['Valute']
    
    def make_format(self, currency):
       
        response = self.exchange_rates()
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                return response[currency]['Value']
        
        return 'Error'
    
    def eur(self):
        
        return self.make_format('EUR')
    
    def usd(self):
        
        return self.make_format('USD')

# %%
r = Rate(format_='full')

# %%
r.exchange_rates()
# Out:
# {'AUD': {'ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': 1,
#   'Name': 'Австралийский доллар',
#   'Value': 58.7462,
#   'Previous': 58.8281},
#  'AZN': {'ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': 1,
#   'Name': 'Азербайджанский манат',
#   'Value': 45.4183,
#   'Previous': 45.3803},
#  'GBP': {'ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': 1,
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': 105.7633,
#   'Previous': 105.9369},
#  'AMD': {'ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': 100,
#   'Name': 'Армянских драмов',
#   'Value': 14.4928,
#   'Previous': 14.4249},
#  'BYN': {'ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': 1,
#   'Name': 'Белорусский рубль',
#   'Value': 29.2018,
#   'Previous': 28.9473},
#  'BGN': {'ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': 1,
# ...

# %%
curr = Rate()
a = curr.exchange_rates()

def get_maximum(data_object):
    maximum_value = 0
    result_currency = ''
    for currency in data_object:
        if data_object[currency]['Value']/data_object[currency]['Nominal'] > maximum_value:
            maximum_value = data_object[currency]['Value']/data_object[currency]['Nominal']
            result_currency = currency
    return data_object[result_currency]['Name']

get_maximum(a)
# Out:
# 'СДР (специальные права заимствования)'

# %%
# Задание 2

# %%
class Rate:
    def __init__(self, format_='value', diff=False):
        self.format = format_
        self.diff = diff
    
    def exchange_rates(self):
        r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return r.json()['Valute']
    
    def make_format(self, currency):
        response = self.exchange_rates()
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                if self.diff:
                    return response[currency]['Value'] - response[currency]['Previous']
                else:
                    return response[currency]['Value']
        
        return 'Err'
    
    def eur(self):
        return self.make_format('EUR')
    
    def usd(self):
        return self.make_format('USD')
    def dkk(self):
        return self.make_format('DKK')
    
Rate(diff=True).dkk()
# Out:
# 0.015499999999999403

# %%
# Задание 3

# %%
class Employee:
    def __init__(self, name, seniority):
        self.name = name
        self.seniority = seniority
        
        self.grade = 1
    
    def grade_up(self):
        """Повышает уровень сотрудника"""
        self.grade += 1
    
    def publish_grade(self):
        """Публикация результатов аккредитации сотрудников"""
        print(self.name, self.grade)
    
    def check_if_it_is_time_for_upgrade(self):
        pass

# %%
from math import floor
class Designer(Employee):
    def __init__(self, name, seniority, raising=2):
        super().__init__(name, seniority)
        self.raising = raising;

    
    def grade(self):
        return floor((self.raising * 2 + self.seniority) / 7)
    
    def give_a_raising(self):
        print ('Повышение на 1 грейд')
        self.raising += 1
        
    def check_if_it_is_time_for_upgrade(self):
        self.seniority += 1

        return self.publish_grade()
        
elena = Designer('Елена',seniority=2);

for i in range(20):
    elena.check_if_it_is_time_for_upgrade()
    
for i in range(5):
    elena.give_a_raising()
for i in range(20):
    elena.check_if_it_is_time_for_upgrade()
# Out:
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Повышение на 1 грейд
# Повышение на 1 грейд
# Повышение на 1 грейд
# Повышение на 1 грейд
# Повышение на 1 грейд
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
# Елена 1
