# %%
#Задание 1**
#Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
#- оценка 2 и меньше - низкий рейтинг
#- оценка 4 и меньше - средний рейтинг
#- оценка 4.5 и 5 - высокий рейтинг

# %%
import pandas as pd

# %%
ratings=pd.read_csv('ratings.csv')
movies=pd.read_csv('movies.csv')

# %%
table = ratings.merge(movies, how='left')

# %%
films_rating = table.groupby('title').mean().reset_index()[['title', 'rating']]

# %%
def classification(row):
    if row['rating'] <= 2.0:
        return 'Низкий'
    elif (row['rating'] > 2.0) and (row['rating'] <= 4.0):
        return 'Средний'
    elif row['rating'] > 4.0:
        return 'Высокий'
    else:
        return 'undefined'
    
# прогоняем функцию с помощью апплай
films_rating['class'] = films_rating.apply(classification, axis=1)


films_rating.head(50)
# Out:
#                                                 title    rating    class
# 0                                          '71 (2014)  4.000000  Средний
# 1             'Hellboy': The Seeds of Creation (2004)  4.000000  Средний
# 2                              'Round Midnight (1986)  3.500000  Средний
# 3                                 'Salem's Lot (2004)  5.000000  Высокий
# 4                           'Til There Was You (1997)  4.000000  Средний
# 5                     'Tis the Season for Love (2015)  1.500000   Низкий
# 6                                  'burbs, The (1989)  3.176471  Средний
# 7                                'night Mother (1986)  3.000000  Средний
# 8                         (500) Days of Summer (2009)  3.666667  Средний
# 9                      *batteries not included (1987)  3.285714  Средний
# 10                          ...All the Marbles (1981)  2.000000   Низкий
# 11                      ...And Justice for All (1979)  3.166667  Средний
# ...

# %%
# Задание 2
#Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону.
#Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. 
#Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#'Центр': ['москва', 'тула', 'ярославль'],

#'Северо-Запад': ['петербург', 'псков', 'мурманск'],

#'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']

# %%
data = pd.read_csv('keywords.csv')

def geo_classifier(row):
    if 'москва' in row['keyword'] or 'тула' in row['keyword'] or 'ярославль' in row['keyword']:
        return 'Центр'
    elif 'петербург' in row['keyword'] or 'псков' in row['keyword'] or 'мурманск' in row['keyword']:
        return 'Северо-Запад'
    elif 'владивосток' in row['keyword'] or 'сахалин' in row['keyword'] or 'хабаровск' in row['keyword']:
        return 'Дальний Восток'
    else:
        return 'undefined'


data['region'] = data.apply(geo_classifier, axis=1)


data['region'].value_counts()
# Out:
# undefined         99281
# Центр               387
# Северо-Запад        238
# Дальний Восток       94
# Name: region, dtype: int64

# %%
#Задание 3 (бонусное)

# %%
ratings=pd.read_csv('ratings.csv')
movies=pd.read_csv('movies.csv')

table = ratings.merge(movies, how='left')

films_rating = table.groupby('title').mean().reset_index()[['title', 'rating']]
films_rating.head()
# Out:
#                                      title  rating
# 0                               '71 (2014)     4.0
# 1  'Hellboy': The Seeds of Creation (2004)     4.0
# 2                   'Round Midnight (1986)     3.5
# 3                      'Salem's Lot (2004)     5.0
# 4                'Til There Was You (1997)     4.0

# %%
years = [str(i+1950) for i in range(61)]
print(years)
# Out:
# ['1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010']

# %%
def production_year(row):
    for year in years:
        if year in row['title']:
            return year
    return '1900'

# %%
films_rating['year'] = films_rating.apply(production_year, axis=1)
films_rating.head(10)
# Out:
#                                      title    rating  year
# 0                               '71 (2014)  4.000000  1900
# 1  'Hellboy': The Seeds of Creation (2004)  4.000000  2004
# 2                   'Round Midnight (1986)  3.500000  1986
# 3                      'Salem's Lot (2004)  5.000000  2004
# 4                'Til There Was You (1997)  4.000000  1997
# 5          'Tis the Season for Love (2015)  1.500000  1900
# 6                       'burbs, The (1989)  3.176471  1989
# 7                     'night Mother (1986)  3.000000  1986
# 8              (500) Days of Summer (2009)  3.666667  2009
# 9           *batteries not included (1987)  3.285714  1987

# %%
films_rating.sort_values('rating', ascending=False).head(10)
# Out:
#                                           title  rating  year
# 3354                  Gena the Crocodile (1969)     5.0  1969
# 8951                        True Stories (1986)     5.0  1986
# 1986              Cosmic Scrat-tastrophe (2015)     5.0  1900
# 5269                    Love and Pigeons (1985)     5.0  1985
# 7033        Red Sorghum (Hong gao liang) (1987)     5.0  1987
# 8661  Thin Line Between Love and Hate, A (1996)     5.0  1996
# 5019                        Lesson Faust (1994)     5.0  1994
# 2799                                 Eva (2011)     5.0  1900
# 9435             Who Killed Chea Vichea? (2010)     5.0  2010
# 7662                         Siam Sunset (1999)     5.0  1999
